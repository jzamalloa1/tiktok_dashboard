# %%
import pandas as pd
import json

# %%
df = pd.read_json("python_dump")
df.head()
# Out:
#                     id                                               desc  \
# 0  6914157190987271168  Oh Julius 😅 "Julius the Python" on YouTube #ju...
# 1  6909838234151422976  stain.. Petit python banana..😍#fyp  #ballpytho...
# 2  6958430060340694016  Happy birthday little buddy 🐍 #snake #python #...
# 3  6980527845726604288  lil too busy worried about snacks.. #Python #d...
# 4  6840796191161175040  Check out this baby python! Did you kno their ...
#
#    createTime                                              video  \
# 0  1609827712  {'id': '6914157190987271430', 'height': 480, '...
# 1  1608822085  {'id': '6909838234151423234', 'height': 960, '...
# 2  1620135755  {'id': '6958430060340694278', 'height': 1024, ...
# 3  1625280797  {'id': '6980527845726604549', 'height': 1024, ...
# 4  1592746983  {'id': '6840796191161175302', 'height': 1024, ...
#
#                                               author  \
# 0  {'id': '6815401436291580934', 'uniqueId': '666...
# 1  {'id': '6879407363858793478', 'uniqueId': 'ale...
# 2  {'id': '6700343527676740613', 'uniqueId': 'the...
# 3  {'id': '6797473463524148230', 'uniqueId': 'cac...
# 4  {'id': '6699542567460389894', 'uniqueId': 'jay...
#
#                                                music  \
# 0  {'id': '6914157155620801286', 'title': 'origin...
# 1  {'id': '6623108046656637701', 'title': 'Follow...
# 2  {'id': '6800370585814697986', 'title': 'Intent...
# 3  {'id': '6980527635675745029', 'title': 'origin...
# 4  {'id': '6754296561716447233', 'title': 'Roses ...
#
#                                           challenges  \
# 0  [{'id': '1688028247347206', 'title': 'juliusth...
# 1  [{'id': '229207', 'title': 'fyp', 'desc': '', ...
# 2  [{'id': '37769', 'title': 'snake', 'desc': 'Il...
# 3  [{'id': '163195', 'title': 'python', 'desc': '...
# 4  [{'id': '1597138111108097', 'title': 'animalso...
#
#                                                stats             duetInfo  \
# 0  {'diggCount': 3500000, 'shareCount': 271800, '...  {'duetFromId': '0'}
# 1  {'diggCount': 2600000, 'shareCount': 36900, 'c...  {'duetFromId': '0'}
# 2  {'diggCount': 2200000, 'shareCount': 16400, 'c...  {'duetFromId': '0'}
# 3  {'diggCount': 1900000, 'shareCount': 38200, 'c...  {'duetFromId': '0'}
# 4  {'diggCount': 1900000, 'shareCount': 15500, 'c...  {'duetFromId': '0'}
#
#    originalItem  ...  privateItem duetEnabled  stitchEnabled  shareEnabled  \
# 0         False  ...        False        True           True          True
# 1         False  ...        False       False          False          True
# 2         False  ...        False       False          False          True
# 3         False  ...        False        True           True          True
# 4         False  ...        False        True           True          True
#
#                                       stickersOnItem   isAd  duetDisplay  \
# 0  [{'stickerType': 4, 'stickerText': ['That time...  False            0
# 1                                                NaN  False            0
# 2                                                NaN  False            0
# 3  [{'stickerType': 9, 'stickerText': ['Dog steps...  False            0
# 4                                                NaN  False            0
#
#    stitchDisplay  warnInfo effectStickers
# 0              0       NaN            NaN
# 1              0       NaN            NaN
# 2              0       NaN            NaN
# 3              0       NaN            NaN
# 4              0       NaN            NaN
#
# [5 rows x 30 columns]

# %%
# [pd.DataFrame(df["video"][i]).shape for i in range(df.shape[0])]
pd.DataFrame(df["video"][0])
# Out:
#                     id  height  width  duration ratio  \
# 0  6914157190987271430     480    640         9  480p
# 1  6914157190987271430     480    640         9  480p
# 2  6914157190987271430     480    640         9  480p
#
#                                                cover  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                          originCover  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                         dynamicCover  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                             playAddr  \
# 0  https://v16-webapp.tiktok.com/e56e0960f2331c5e...
# 1  https://v16-webapp.tiktok.com/e56e0960f2331c5e...
# 2  https://v16-webapp.tiktok.com/e56e0960f2331c5e...
#
#                                         downloadAddr  \
# 0  https://v16-webapp.tiktok.com/e56e0960f2331c5e...
# 1  https://v16-webapp.tiktok.com/e56e0960f2331c5e...
# 2  https://v16-webapp.tiktok.com/e56e0960f2331c5e...
#
#                                           shareCover  \
# 0
# 1  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 2  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
#
#                                          reflowCover  bitrate encodedType  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...   418808      normal
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...   418808      normal
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...   418808      normal
#
#   format videoQuality encodeUserTag codecType definition
# 0    mp4       normal                    h264       480p
# 1    mp4       normal                    h264       480p
# 2    mp4       normal                    h264       480p

# %%
with open("python_dump", "r") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'id': '6914157190987271430',
#   'desc': 'Oh Julius 😅 "Julius the Python" on YouTube #juliusthesnake #python #snakes #petsnakes #reptiles #bigsnakes #exoticpet #burmesepython #funnyanimals',
#   'createTime': 1609827712,
#   'video': {'id': '6914157190987271430',
#    'height': 480,
#    'width': 640,
#    'duration': 9,
#    'ratio': '480p',
#    'cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8b44ab15bd64f4ba820bc477f485a10_1609827713?x-expires=1644210000&x-signature=SUInSDyvUToj5%2BZdjd4lCFUU%2FBM%3D',
#    'originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713?x-expires=1644210000&x-signature=pyNPKSMpCoBdZ62Go0XQC21GyYQ%3D',
#    'dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/ec2039a008c24b859c00aa3aa3971c9c_1609827714?x-expires=1644210000&x-signature=QkkKGhPa%2BZLhYKi5k%2F%2FrpoNgwPQ%3D',
#    'playAddr': 'https://v16-webapp.tiktok.com/e56e0960f2331c5eb92a95687c6424e9/6200a878/video/tos/useast2a/tos-useast2a-ve-0068c001/027aa7b9454044f98520401bbb5eaf44/?a=1988&br=816&bt=408&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=2&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajV1eXNtNXkzeTMzNTczM0ApNDo8OmY0Mzs3N2lkOzhnZGduNHM2NDAwXm5fLS1fMTZzczIzYy9iYDAyMTJgNjYwYWM6Yw%3D%3D&vl=&vr=',
#    'downloadAddr': 'https://v16-webapp.tiktok.com/e56e0960f2331c5eb92a95687c6424e9/6200a878/video/tos/useast2a/tos-useast2a-ve-0068c001/027aa7b9454044f98520401bbb5eaf44/?a=1988&br=816&bt=408&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=2&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajV1eXNtNXkzeTMzNTczM0ApNDo8OmY0Mzs3N2lkOzhnZGduNHM2NDAwXm5fLS1fMTZzczIzYy9iYDAyMTJgNjYwYWM6Yw%3D%3D&vl=&vr=',
#    'shareCover': ['',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=shoOWtTHh27WBO1ZfJBNY%2FUyE2M%3D',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=WoHTEYASSjN3wuS3READto9f84w%3D'],
#    'reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8b44ab15bd64f4ba820bc477f485a10_1609827713?x-expires=1644210000&x-signature=SUInSDyvUToj5%2BZdjd4lCFUU%2FBM%3D',
#    'bitrate': 418808,
#    'encodedType': 'normal',
#    'format': 'mp4',
#    'videoQuality': 'normal',
#    'encodeUserTag': '',
#    'codecType': 'h264',
#    'definition': '480p'},
#   'author': {'id': '6815401436291580934',
#    'uniqueId': '666zomey',
#    'nickname': 'Zomey',
#    'avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_100x100.jpeg?x-expires=1644274800&x-signature=s6cfURS%2BvYpA3UZRITQMdJ%2BOn%2FA%3D',
#    'avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_720x720.jpeg?x-expires=1644274800&x-signature=HxG4uLswBqFSVnxh%2BGftMdKAIQM%3D',
#    'avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=%2B6JIHFjIYl4SzGFAN%2FR%2BHx56HZ8%3D',
#    'signature': "~ PDX. 🏳️\u200d🌈. Wine. Animals. Humor ~\nInsta '666zomey'\n$zomey666",
#    'verified': False,
#    'secUid': 'MS4wLjABAAAAmKLjce6rFzxV0HuEfYOm5dh-tCsyPyhTdnqj-ebq1Hozp7r91zmbf3-6UirgSZhm',
#    'secret': False,
#    'ftc': False,
#    'relation': 0,
#    'openFavorite': False,
#    'commentSetting': 0,
#    'duetSetting': 0,
#    'stitchSetting': 0,
#    'privateAccount': False,
#    'isADVirtual': False},
#   'music': {'id': '6914157155620801286',
#    'title': 'original sound',
#    'playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6914157149086108421.mp3',
#    'coverThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_100x100.jpeg?x-expires=1644274800&x-signature=s6cfURS%2BvYpA3UZRITQMdJ%2BOn%2FA%3D',
#    'coverMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_720x720.jpeg?x-expires=1644274800&x-signature=HxG4uLswBqFSVnxh%2BGftMdKAIQM%3D',
#    'coverLarge': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=%2B6JIHFjIYl4SzGFAN%2FR%2BHx56HZ8%3D',
#    'authorName': 'Zomey',
#    'original': True,
#    'duration': 8,
#    'album': ''},
#   'challenges': [{'id': '1688028247347206',
#     'title': 'juliusthesnake',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '163195',
#     'title': 'python',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '55989',
#     'title': 'snakes',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '12175144',
#     'title': 'petsnakes',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '204835',
#     'title': 'reptiles',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '14708816',
#     'title': 'bigsnakes',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '12390175',
#     'title': 'exoticpet',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '17154764',
#     'title': 'burmesepython',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '487800',
#     'title': 'funnyanimals',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False}],
#   'stats': {'diggCount': 3500000,
#    'shareCount': 271800,
#    'commentCount': 72900,
#    'playCount': 26600000},
#   'duetInfo': {'duetFromId': '0'},
#   'originalItem': False,
#   'officalItem': False,
#   'textExtra': [{'awemeId': '',
#     'start': 44,
#     'end': 59,
#     'hashtagName': 'juliusthesnake',
#     'hashtagId': '1688028247347206',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 60,
#     'end': 67,
#     'hashtagName': 'python',
#     'hashtagId': '163195',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 68,
#     'end': 75,
#     'hashtagName': 'snakes',
#     'hashtagId': '55989',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 76,
#     'end': 86,
#     'hashtagName': 'petsnakes',
#     'hashtagId': '12175144',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 87,
#     'end': 96,
#     'hashtagName': 'reptiles',
#     'hashtagId': '204835',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 97,
#     'end': 107,
#     'hashtagName': 'bigsnakes',
#     'hashtagId': '14708816',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 108,
#     'end': 118,
#     'hashtagName': 'exoticpet',
#     'hashtagId': '12390175',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 119,
#     'end': 133,
#     'hashtagName': 'burmesepython',
#     'hashtagId': '17154764',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 134,
#     'end': 147,
#     'hashtagName': 'funnyanimals',
#     'hashtagId': '487800',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0}],
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats': {'followingCount': 737,
#    'followerCount': 105100,
#    'heartCount': 4700000,
#    'videoCount': 192,
#    'diggCount': 3583,
#    'heart': 4700000},
#   'privateItem': False,
#   'duetEnabled': True,
#   'stitchEnabled': True,
#   'shareEnabled': True,
#   'stickersOnItem': [{'stickerType': 4,
#     'stickerText': ['That time my girlfriends python, Julius... ',
#      'Learned how to open doors 😅']}],
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  {'id': '6909838234151423234',
#   'desc': 'stain.. Petit python banana..😍#fyp  #ballpython #serpent #python #snake #reptile #pourtoi #foryou #dance #drums',
#   'createTime': 1608822085,
#   'video': {'id': '6909838234151423234',
#    'height': 960,
#    'width': 540,
#    'duration': 15,
#    'ratio': '720p',
#    'cover': 'https://p16-sign-sg.tiktokcdn.com/obj/tos-alisg-p-0037/a466eb2e38684e8dbc8819b623f04310?x-expires=1644210000&x-signature=FNVcU6UDoQ6BvVeqG4VlzoZs6h0%3D',
#    'originCover': 'https://p16-sign-sg.tiktokcdn.com/obj/tos-alisg-p-0037/4006d0b95ee640f697417f67441e905e_1608822090?x-expires=1644210000&x-signature=F3po4ov%2FL3b3wPRwaRA6IFrPl0I%3D',
#    'dynamicCover': 'https://p16-sign-sg.tiktokcdn.com/obj/tos-alisg-p-0037/ba8793c95cc340b4b5c823237cdc1e64_1608822091?x-expires=1644210000&x-signature=yKgwLD0SoTNX3nA9Gvc0z%2B2Cj1M%3D',
#    'playAddr': 'https://v16-webapp.tiktok.com/35ce98357849eb02a1a5a0e0b7878c9b/6200a87e/video/tos/alisg/tos-alisg-pve-0037c001/5278f75a740e40f8a3cb6857f7489c42/?a=1988&br=2602&bt=1301&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=anA7dGh0NGZkeTMzNzczM0ApNTllODQzNDtkNzw1M2ZlZ2dqY2MzXmFqbmZfLS1fMTRzc2ExMWBfXzJiYjJeXjMvNmI6Yw%3D%3D&vl=&vr=',
#    'downloadAddr': 'https://v16-webapp.tiktok.com/35ce98357849eb02a1a5a0e0b7878c9b/6200a87e/video/tos/alisg/tos-alisg-pve-0037c001/5278f75a740e40f8a3cb6857f7489c42/?a=1988&br=2602&bt=1301&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=anA7dGh0NGZkeTMzNzczM0ApNTllODQzNDtkNzw1M2ZlZ2dqY2MzXmFqbmZfLS1fMTRzc2ExMWBfXzJiYjJeXjMvNmI6Yw%3D%3D&vl=&vr=',
#    'shareCover': ['',
#     'https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-0037/4006d0b95ee640f697417f67441e905e_1608822090~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=5IJugLfi3RjC16zJFuMS6x6vYIk%3D',
#     'https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-0037/4006d0b95ee640f697417f67441e905e_1608822090~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=MhEG6k8p80C4CS3ha2fPh6YV9bQ%3D'],
#    'reflowCover': 'https://p16-sign-sg.tiktokcdn.com/obj/tos-alisg-p-0037/a466eb2e38684e8dbc8819b623f04310?x-expires=1644210000&x-signature=FNVcU6UDoQ6BvVeqG4VlzoZs6h0%3D',
#    'bitrate': 1332748,
#    'encodedType': 'normal',
#    'format': 'mp4',
#    'videoQuality': 'normal',
#    'encodeUserTag': '',
#    'codecType': 'h264',
#    'definition': '720p'},
#   'author': {'id': '6879407363858793478',
#    'uniqueId': 'alexenzoo',
#    'nickname': '🐍alexenzoo🐍',
#    'avatarThumb': 'https://p16-sign-sg.tiktokcdn.com/aweme/100x100/tos-alisg-avt-0068/1ecc187d28f535f53f25191b20d3b7f4.jpeg?x-expires=1644274800&x-signature=5WCf9%2BdJxDaCGeqNIbiLiO7WtS8%3D',
#    'avatarMedium': 'https://p16-sign-sg.tiktokcdn.com/aweme/720x720/tos-alisg-avt-0068/1ecc187d28f535f53f25191b20d3b7f4.jpeg?x-expires=1644274800&x-signature=mytRALDCyfVqlK8ltIgX5EkQDzI%3D',
#    'avatarLarger': 'https://p16-sign-sg.tiktokcdn.com/aweme/1080x1080/tos-alisg-avt-0068/1ecc187d28f535f53f25191b20d3b7f4.jpeg?x-expires=1644274800&x-signature=yAPzUphta2pE34IcJt5IoCXvHjQ%3D',
#    'signature': 'Mes compagnons 🐍🦜🐠\nInstagram: @alexenzoox',
#    'verified': False,
#    'secUid': 'MS4wLjABAAAA9tlAtHtHu50wzqKK0K8G__YMLPB09ck3J-GQqhepndSaVHsy_cET3Tj_ujE3kziM',
#    'secret': False,
#    'ftc': False,
#    'relation': 0,
#    'openFavorite': False,
#    'commentSetting': 0,
#    'duetSetting': 0,
#    'stitchSetting': 0,
#    'privateAccount': False,
#    'isADVirtual': False},
#   'music': {'id': '6623108046656637701',
#    'title': 'Follow pepperonijoe',
#    'playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/1616970010746885',
#    'coverThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/eef8d45ff6dc27842227e35aa2dc8b27~c5_100x100.jpeg?x-expires=1644274800&x-signature=AAHqnTVD0Lbh3KHj5V4wyFdNATk%3D',
#    'coverMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/eef8d45ff6dc27842227e35aa2dc8b27~c5_720x720.jpeg?x-expires=1644274800&x-signature=71ImperH%2F5ZhgU%2FgDkyP5%2FzBkxk%3D',
#    'coverLarge': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/eef8d45ff6dc27842227e35aa2dc8b27~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=dr8MqvUpz5JJUK%2B1ZXk4TMIs8TU%3D',
#    'authorName': 'Joe',
#    'original': True,
#    'duration': 16,
#    'album': 'pepperonijoe'},
#   'challenges': [{'id': '229207',
#     'title': 'fyp',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '126343',
#     'title': 'ballpython',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '1522395',
#     'title': 'serpent',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '163195',
#     'title': 'python',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '37769',
#     'title': 'snake',
#     'desc': 'Il trend del momento ♫',
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '132399',
#     'title': 'reptile',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '2852101',
#     'title': 'pourtoi',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '42164',
#     'title': 'foryou',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '5054',
#     'title': 'dance',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '1644',
#     'title': 'drums',
#     'desc': 'D is for Drums...',
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/d712d8192dc27e9b13733ea232d2b116',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/d712d8192dc27e9b13733ea232d2b116',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/d712d8192dc27e9b13733ea232d2b116',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False}],
#   'stats': {'diggCount': 2600000,
#    'shareCount': 36900,
#    'commentCount': 24900,
#    'playCount': 53500000},
#   'duetInfo': {'duetFromId': '0'},
#   'originalItem': False,
#   'officalItem': False,
#   'textExtra': [{'awemeId': '',
#     'start': 31,
#     'end': 35,
#     'hashtagName': 'fyp',
#     'hashtagId': '229207',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 37,
#     'end': 48,
#     'hashtagName': 'ballpython',
#     'hashtagId': '126343',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 49,
#     'end': 57,
#     'hashtagName': 'serpent',
#     'hashtagId': '1522395',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 58,
#     'end': 65,
#     'hashtagName': 'python',
#     'hashtagId': '163195',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 66,
#     'end': 72,
#     'hashtagName': 'snake',
#     'hashtagId': '37769',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 73,
#     'end': 81,
#     'hashtagName': 'reptile',
#     'hashtagId': '132399',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 82,
#     'end': 90,
#     'hashtagName': 'pourtoi',
#     'hashtagId': '2852101',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 91,
#     'end': 98,
#     'hashtagName': 'foryou',
#     'hashtagId': '42164',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 99,
#     'end': 105,
#     'hashtagName': 'dance',
#     'hashtagId': '5054',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 106,
#     'end': 112,
#     'hashtagName': 'drums',
#     'hashtagId': '1644',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0}],
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats': {'followingCount': 11,
#    'followerCount': 1100000,
#    'heartCount': 5900000,
#    'videoCount': 236,
#    'diggCount': 2390,
#    'heart': 5900000},
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  {'id': '6958430060340694278',
#   'desc': 'Happy birthday little buddy 🐍 #snake #python #birthday',
#   'createTime': 1620135755,
#   'video': {'id': '6958430060340694278',
#    'height': 1024,
#    'width': 576,
#    'duration': 20,
#    'ratio': '720p',
#    'cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/4f9d0765d2694c2ea0c993c602630912_1620135757?x-expires=1644210000&x-signature=InWNZKQkDPOPjpJNAKdxvvUV4SY%3D',
#    'originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/32bf5c5e89fe40dea457cf16fd909de7_1620135756?x-expires=1644210000&x-signature=YE1JGJpMB%2BIuYWFsU3iQVN3Ebnw%3D',
#    'dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/57c7dd1853d2406f998d62113e679238_1620135756?x-expires=1644210000&x-signature=Ndlg3K2OnTjHTMkaN1vq2i9C7nQ%3D',
#    'playAddr': 'https://v16-webapp.tiktok.com/1045720dc3bad99f4db5784543995f4b/6200a883/video/tos/useast2a/tos-useast2a-ve-0068c003/eafe93d235ac4da39550af4837007f13/?a=1988&br=3464&bt=1732&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M2k0bDg7ajluNTMzNzczM0ApODg5OTtoZ2VkN2hoNTg1O2czcF9vbmhgcjVgLS1kMTZzcy0wNC5eYi81MS1eYDMvMV46Yw%3D%3D&vl=&vr=',
#    'downloadAddr': 'https://v16-webapp.tiktok.com/1045720dc3bad99f4db5784543995f4b/6200a883/video/tos/useast2a/tos-useast2a-ve-0068c003/eafe93d235ac4da39550af4837007f13/?a=1988&br=3464&bt=1732&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M2k0bDg7ajluNTMzNzczM0ApODg5OTtoZ2VkN2hoNTg1O2czcF9vbmhgcjVgLS1kMTZzcy0wNC5eYi81MS1eYDMvMV46Yw%3D%3D&vl=&vr=',
#    'shareCover': ['',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/32bf5c5e89fe40dea457cf16fd909de7_1620135756~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=prDuHpVX%2BXAwY0VCC8rNbBij518%3D',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/32bf5c5e89fe40dea457cf16fd909de7_1620135756~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=2%2FRYHKXe1k5jZcfcxQSRrfmP2fY%3D'],
#    'reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/9261e2981c94793d9e81f6c7f6e3306b?x-expires=1644210000&x-signature=w5TCfRXIoZXG%2Fx9KuQcbwc8luSc%3D',
#    'bitrate': 1773607,
#    'encodedType': 'normal',
#    'format': 'mp4',
#    'videoQuality': 'normal',
#    'encodeUserTag': '',
#    'codecType': 'h264',
#    'definition': '720p'},
#   'author': {'id': '6700343527676740613',
#    'uniqueId': 'thereptilezoo',
#    'nickname': 'The Reptile Zoo',
#    'avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1636362969334789~c5_100x100.jpeg?x-expires=1644274800&x-signature=fcBVz25w%2Bw7Bt1suOMgrhciyCMk%3D',
#    'avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1636362969334789~c5_720x720.jpeg?x-expires=1644274800&x-signature=qq2TP2Ipv7J12Og2MLY5RbuQNyw%3D',
#    'avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1636362969334789~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=XBB4KRv%2FMn1ILpG3hL9d1hLCGVE%3D',
#    'signature': 'If it hops, wiggles, or gives your \nmom the chills, we’ve got it here!',
#    'verified': True,
#    'secUid': 'MS4wLjABAAAAqaXgkJaDFfLRDI8ZrIf-Z0rLZdtJIkxflEjhgIt5CjPJC91WcNku4vYvFPbkRpxm',
#    'secret': False,
#    'ftc': False,
#    'relation': 0,
#    'openFavorite': False,
#    'commentSetting': 0,
#    'duetSetting': 0,
#    'stitchSetting': 0,
#    'privateAccount': False,
#    'isADVirtual': False},
#   'music': {'id': '6800370585814697986',
#    'title': 'Intentions (Instrumental Version) [Originally Performed by Justin Bieber & Quavo]',
#    'playUrl': 'https://sf16-ies-music-sg.tiktokcdn.com/obj/tos-alisg-ve-2774/36ecd374967d46c3a394dab30a059cca',
#    'coverThumb': 'https://p16-sg.tiktokcdn.com/aweme/100x100/tos-alisg-v-2774/25636085cff34e3b97f2f24244ae8937.jpeg',
#    'coverMedium': 'https://p16-sg.tiktokcdn.com/aweme/200x200/tos-alisg-v-2774/25636085cff34e3b97f2f24244ae8937.jpeg',
#    'coverLarge': 'https://p16-sg.tiktokcdn.com/aweme/720x720/tos-alisg-v-2774/25636085cff34e3b97f2f24244ae8937.jpeg',
#    'authorName': 'Elliot Van Coup',
#    'original': False,
#    'duration': 60,
#    'album': 'Blast Thru Hits vol 3'},
#   'challenges': [{'id': '37769',
#     'title': 'snake',
#     'desc': 'Il trend del momento ♫',
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '163195',
#     'title': 'python',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '10007',
#     'title': 'birthday',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False}],
#   'stats': {'diggCount': 2200000,
#    'shareCount': 16400,
#    'commentCount': 9423,
#    'playCount': 26900000},
#   'duetInfo': {'duetFromId': '0'},
#   'originalItem': False,
#   'officalItem': False,
#   'textExtra': [{'awemeId': '',
#     'start': 31,
#     'end': 37,
#     'hashtagName': 'snake',
#     'hashtagId': '37769',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 38,
#     'end': 45,
#     'hashtagName': 'python',
#     'hashtagId': '163195',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 46,
#     'end': 55,
#     'hashtagName': 'birthday',
#     'hashtagId': '10007',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0}],
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats': {'followingCount': 33,
#    'followerCount': 11300000,
#    'heartCount': 151200000,
#    'videoCount': 636,
#    'diggCount': 357,
#    'heart': 151200000},
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  {'id': '6980527845726604549',
#   'desc': 'lil too busy worried about snacks.. #Python #dog #snakesoftiktok #NatureTikTok',
#   'createTime': 1625280797,
#   'video': {'id': '6980527845726604549',
#    'height': 1024,
#    'width': 576,
#    'duration': 7,
#    'ratio': '720p',
#    'cover': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/70880fd346df40fb9b19dda921c29375~tplv-dmt-logom:tos-maliva-p-0000/d3e787e3f5e34ff9a8d77cf2e09ecfb0.image?x-expires=1644210000&x-signature=RG3KM75DNQLVJlWdBvMNYbT2xzQ%3D',
#    'originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/3fa616b9d6ef40abad723b77a263df17_1625280798?x-expires=1644210000&x-signature=pCPizYVYrejwZivO%2BbxE465pvi0%3D',
#    'dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/c7e0a9bb0006444a964d2530e71ba6b2_1625280799?x-expires=1644210000&x-signature=RBd34YQkvuNTh2yw3lONf488%2FpY%3D',
#    'playAddr': 'https://v16-webapp.tiktok.com/66eaced87c90a99c77b6c9bcea307e4e/6200a875/video/tos/useast2a/tos-useast2a-ve-0068c002/84ed739392bc4e6781e95af8530678ac/?a=1988&br=2406&bt=1203&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M3I1ZGZ3amh2NjMzNzczM0ApNDM3NmU1PGVnN2czNjQ6O2diNS9vaTBvc2NgLS1kMTZzczIvXi4uMS0xNmBhYjJgYGM6Yw%3D%3D&vl=&vr=',
#    'downloadAddr': 'https://v16-webapp.tiktok.com/66eaced87c90a99c77b6c9bcea307e4e/6200a875/video/tos/useast2a/tos-useast2a-ve-0068c002/84ed739392bc4e6781e95af8530678ac/?a=1988&br=2406&bt=1203&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=M3I1ZGZ3amh2NjMzNzczM0ApNDM3NmU1PGVnN2czNjQ6O2diNS9vaTBvc2NgLS1kMTZzczIvXi4uMS0xNmBhYjJgYGM6Yw%3D%3D&vl=&vr=',
#    'shareCover': ['',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/3fa616b9d6ef40abad723b77a263df17_1625280798~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=ofrsG%2F0%2FFf6%2FturXYGaUuBVOfZ0%3D',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/3fa616b9d6ef40abad723b77a263df17_1625280798~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=eytbcobQ7i1%2FaUq6xaDAdkAlHtg%3D'],
#    'reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/bbdcc4281bf3163e1b77aba9f55cef4e?x-expires=1644210000&x-signature=Lo736%2FifqYwCG0EQTsVMvI3u%2Bhc%3D',
#    'bitrate': 1232421,
#    'encodedType': 'normal',
#    'format': 'mp4',
#    'videoQuality': 'normal',
#    'encodeUserTag': '',
#    'codecType': 'h264',
#    'definition': '720p'},
#   'author': {'id': '6797473463524148230',
#    'uniqueId': 'cactusshark888',
#    'nickname': 'CactusShark',
#    'avatarThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/381f2ba24a1ed6ec42be3100d92b1dbe~c5_100x100.jpeg?x-expires=1644274800&x-signature=6fXBuoOqP0K%2BlCR70Aiy94yIrbQ%3D',
#    'avatarMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/381f2ba24a1ed6ec42be3100d92b1dbe~c5_720x720.jpeg?x-expires=1644274800&x-signature=bHbDUF57p1MC%2F6Y%2Fj2M7W2C6C1w%3D',
#    'avatarLarger': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/381f2ba24a1ed6ec42be3100d92b1dbe~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=K1oV2ZWvG2wAx3f2dMpUJ8GrcDs%3D',
#    'signature': 'Just let me embarrass myself in peace\nSatire Alien 👽 \n•888•\nIG: CactusShark88',
#    'verified': False,
#    'secUid': 'MS4wLjABAAAAoueQN13l88TD-rxyygyAyC031WA7By44ae2JTuuPlutobUxraLNFMD2sRKjxqYov',
#    'secret': False,
#    'ftc': False,
#    'relation': 0,
#    'openFavorite': False,
#    'commentSetting': 0,
#    'duetSetting': 0,
#    'stitchSetting': 0,
#    'privateAccount': False,
#    'isADVirtual': False},
#   'music': {'id': '6980527635675745029',
#    'title': 'original sound',
#    'playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6980527777556466437.mp3',
#    'coverThumb': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/381f2ba24a1ed6ec42be3100d92b1dbe~c5_100x100.jpeg?x-expires=1644274800&x-signature=6fXBuoOqP0K%2BlCR70Aiy94yIrbQ%3D',
#    'coverMedium': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/381f2ba24a1ed6ec42be3100d92b1dbe~c5_720x720.jpeg?x-expires=1644274800&x-signature=bHbDUF57p1MC%2F6Y%2Fj2M7W2C6C1w%3D',
#    'coverLarge': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/381f2ba24a1ed6ec42be3100d92b1dbe~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=K1oV2ZWvG2wAx3f2dMpUJ8GrcDs%3D',
#    'authorName': 'CactusShark',
#    'original': True,
#    'duration': 6,
#    'album': ''},
#   'challenges': [{'id': '163195',
#     'title': 'python',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '6221',
#     'title': 'dog',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '1613548279510021',
#     'title': 'snakesoftiktok',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '1612330118626310',
#     'title': 'naturetiktok',
#     'desc': 'Breathe in the fresh air and enjoy #NatureTikTok.',
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/4cefd82e2cfa02ca1393555a89243bf0',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/4cefd82e2cfa02ca1393555a89243bf0',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/4cefd82e2cfa02ca1393555a89243bf0',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False}],
#   'stats': {'diggCount': 1900000,
#    'shareCount': 38200,
#    'commentCount': 6544,
#    'playCount': 17500000},
#   'duetInfo': {'duetFromId': '0'},
#   'originalItem': False,
#   'officalItem': False,
#   'textExtra': [{'awemeId': '',
#     'start': 36,
#     'end': 43,
#     'hashtagName': 'python',
#     'hashtagId': '163195',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 44,
#     'end': 48,
#     'hashtagName': 'dog',
#     'hashtagId': '6221',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 49,
#     'end': 64,
#     'hashtagName': 'snakesoftiktok',
#     'hashtagId': '1613548279510021',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 65,
#     'end': 78,
#     'hashtagName': 'naturetiktok',
#     'hashtagId': '1612330118626310',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0}],
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats': {'followingCount': 2013,
#    'followerCount': 177200,
#    'heartCount': 16900000,
#    'videoCount': 713,
#    'diggCount': 8712,
#    'heart': 16900000},
#   'privateItem': False,
#   'duetEnabled': True,
#   'stitchEnabled': True,
#   'shareEnabled': True,
#   'stickersOnItem': [{'stickerType': 9,
#     'stickerText': ['Dog steps \non snake!']}],
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  {'id': '6840796191161175302',
#   'desc': 'Check out this baby python! Did you kno their eggs are leathery? #animalsoftiktok #python #snake #egg',
#   'createTime': 1592746983,
#   'video': {'id': '6840796191161175302',
#    'height': 1024,
#    'width': 576,
#    'duration': 18,
#    'ratio': '720p',
#    'cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/0b47a6dc69294b238fc8500cbc8bef65?x-expires=1644210000&x-signature=Gj47J0EOhUJQNKqITCUa6h7bpHo%3D',
#    'originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/393acd9ea3784c9a99c1b086a804325a_1592746986?x-expires=1644210000&x-signature=CaAuJ4rN%2BiksGOTNITLNR%2Ferwzc%3D',
#    'dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/486a80ff07e54a9cbd97e5df5ffe3c45_1592746985?x-expires=1644210000&x-signature=Yuzg%2FP%2BgV8syOdr1WQsCdyrxNIM%3D',
#    'playAddr': 'https://v16-webapp.tiktok.com/3ae90894e3ad75d90e6ab8c1a11911d1/6200a882/video/tos/useast2a/tos-useast2a-ve-0068c002/3edf6856a8a54a2b8e4e07c645660a44/?a=1988&br=3188&bt=1594&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajlrbjp4N3BwdTMzODczM0ApaThmZGY1aWVkNzo0OjpmaWdjaWEuLTJoNGtfLS0tMTZzczE0M15eXmIwXjFeXzA2X2A6Yw%3D%3D&vl=&vr=',
#    'downloadAddr': 'https://v16-webapp.tiktok.com/3ae90894e3ad75d90e6ab8c1a11911d1/6200a882/video/tos/useast2a/tos-useast2a-ve-0068c002/3edf6856a8a54a2b8e4e07c645660a44/?a=1988&br=3188&bt=1594&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajlrbjp4N3BwdTMzODczM0ApaThmZGY1aWVkNzo0OjpmaWdjaWEuLTJoNGtfLS0tMTZzczE0M15eXmIwXjFeXzA2X2A6Yw%3D%3D&vl=&vr=',
#    'shareCover': ['',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/393acd9ea3784c9a99c1b086a804325a_1592746986~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=KEkqR2OgKexx18zyWoMhQ9fFydU%3D',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/393acd9ea3784c9a99c1b086a804325a_1592746986~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=ovphsK0tjk%2FJVtqg47FhLKB9KMM%3D'],
#    'reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/0b47a6dc69294b238fc8500cbc8bef65?x-expires=1644210000&x-signature=Gj47J0EOhUJQNKqITCUa6h7bpHo%3D',
#    'bitrate': 1633245,
#    'encodedType': 'normal',
#    'format': 'mp4',
#    'videoQuality': 'normal',
#    'encodeUserTag': '',
#    'codecType': 'h264',
#    'definition': '720p'},
#   'author': {'id': '6699542567460389894',
#    'uniqueId': 'jayprehistoricpets',
#    'nickname': 'Jay Brewer',
#    'avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_100x100.jpeg?x-expires=1644274800&x-signature=ySoYnE4ZGrNw1UvrWRBvt02%2BkgI%3D',
#    'avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_720x720.jpeg?x-expires=1644274800&x-signature=NmgLKIE46gsC1dtIZwLfG84xu98%3D',
#    'avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=PknVltC49WtWXGM%2FRh%2B3JeI%2BCnI%3D',
#    'signature': 'Sub to my YouTube for even more animal fun see you here on TikTok tomorrow 🤗🙌',
#    'verified': True,
#    'secUid': 'MS4wLjABAAAAKtlitna177EaY3JAgDPnjAfZj8kI-GnaM5hU9HPzaEQzcuj976k3NYbmpX9cyxc2',
#    'secret': False,
#    'ftc': False,
#    'relation': 0,
#    'openFavorite': False,
#    'commentSetting': 0,
#    'duetSetting': 0,
#    'stitchSetting': 0,
#    'privateAccount': False,
#    'isADVirtual': False},
#   'music': {'id': '6754296561716447233',
#    'title': 'Roses (Imanbek Remix)',
#    'playUrl': 'https://sf16-ies-music-sg.tiktokcdn.com/obj/tos-alisg-ve-2774/7cb6f603e624437d850db5262593e355',
#    'coverThumb': 'https://p16-sg.tiktokcdn.com/aweme/100x100/tos-alisg-v-2774/343880cc1dfd49f7a3b99ffe891fb052.jpeg',
#    'coverMedium': 'https://p16-sg.tiktokcdn.com/aweme/200x200/tos-alisg-v-2774/343880cc1dfd49f7a3b99ffe891fb052.jpeg',
#    'coverLarge': 'https://p16-sg.tiktokcdn.com/aweme/720x720/tos-alisg-v-2774/343880cc1dfd49f7a3b99ffe891fb052.jpeg',
#    'authorName': 'SAINt JHN',
#    'original': False,
#    'duration': 60,
#    'album': 'Roses (Imanbek Remix)'},
#   'challenges': [{'id': '1597138111108097',
#     'title': 'animalsoftiktok',
#     'desc': "Whether you're booping your floof, hanging out with some trash pandas or splashing around with your animal roommate, show us all of the #AnimalsOfTikTok.",
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/9b068600b88649e64078bf7dd674ad33',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/9b068600b88649e64078bf7dd674ad33',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/9b068600b88649e64078bf7dd674ad33',
#     'coverThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/38d81422f775dc1283ad4a2430077ee1',
#     'coverMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/38d81422f775dc1283ad4a2430077ee1',
#     'coverLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/38d81422f775dc1283ad4a2430077ee1',
#     'isCommerce': False},
#    {'id': '163195',
#     'title': 'python',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '37769',
#     'title': 'snake',
#     'desc': 'Il trend del momento ♫',
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '68029',
#     'title': 'egg',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False}],
#   'stats': {'diggCount': 1900000,
#    'shareCount': 15500,
#    'commentCount': 10900,
#    'playCount': 23400000},
#   'duetInfo': {'duetFromId': '0'},
#   'originalItem': False,
#   'officalItem': False,
#   'textExtra': [{'awemeId': '',
#     'start': 65,
#     'end': 81,
#     'hashtagName': 'animalsoftiktok',
#     'hashtagId': '1597138111108097',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 82,
#     'end': 89,
#     'hashtagName': 'python',
#     'hashtagId': '163195',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 90,
#     'end': 96,
#     'hashtagName': 'snake',
#     'hashtagId': '37769',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 97,
#     'end': 101,
#     'hashtagName': 'egg',
#     'hashtagId': '68029',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0}],
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats': {'followingCount': 82,
#    'followerCount': 17400000,
#    'heartCount': 232500000,
#    'videoCount': 782,
#    'diggCount': 17200,
#    'heart': 232500000},
#   'privateItem': False,
#   'duetEnabled': True,
#   'stitchEnabled': True,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  {'id': '6755879345597828357',
#   'desc': 'Helping my 20 foot pet snake shed... #reptiles #python #animals #4u',
#   'createTime': 1572975739,
#   'video': {'id': '6755879345597828357',
#    'height': 1280,
#    'width': 720,
#    'duration': 31,
#    'ratio': '720p',
#    'cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/1c86e1650b5a48e68dae7029c8c4deab_1572975742?x-expires=1644210000&x-signature=3qfocJeRj2BwmrYcBgiImIelGBc%3D',
#    'originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/85f97904eea44a6d92f269026fc7e64e_1572975742?x-expires=1644210000&x-signature=%2BR9VGR%2F58AIjhge5ZkmRkx1XR8I%3D',
#    'dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/22618376bd654561a871342d95ff8c4d_1572975743?x-expires=1644210000&x-signature=DyL3OCtziTPWDnF8d2CMM9H4Wmg%3D',
#    'playAddr': 'https://v16-webapp.tiktok.com/8669d0b33520657b8bc015fa43a953a4/6200a88e/video/tos/useast2a/tos-useast2a-ve-0068/ccd604129eda437c84c01ba6ae78b5d9/?a=1988&br=6644&bt=3322&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajtocnN1bWZ1cTMzNjczM0ApNmdlZDw4ZDxlNzhpNThkZ2c0bTZzbG5mNS1fLS1eMTZzc2FfMjQtM2E2YDZiXmMxMi06Yw%3D%3D&vl=&vr=',
#    'downloadAddr': 'https://v16-webapp.tiktok.com/8669d0b33520657b8bc015fa43a953a4/6200a88e/video/tos/useast2a/tos-useast2a-ve-0068/ccd604129eda437c84c01ba6ae78b5d9/?a=1988&br=6644&bt=3322&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajtocnN1bWZ1cTMzNjczM0ApNmdlZDw4ZDxlNzhpNThkZ2c0bTZzbG5mNS1fLS1eMTZzc2FfMjQtM2E2YDZiXmMxMi06Yw%3D%3D&vl=&vr=',
#    'shareCover': ['',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/85f97904eea44a6d92f269026fc7e64e_1572975742~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=fzlyjFlT4Pyhk%2BnKxzA%2FBSQSqjY%3D',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/85f97904eea44a6d92f269026fc7e64e_1572975742~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=5N%2Fvkbwit7Q9gcM7mThgt4p8NQI%3D'],
#    'reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/1c86e1650b5a48e68dae7029c8c4deab_1572975742?x-expires=1644210000&x-signature=3qfocJeRj2BwmrYcBgiImIelGBc%3D',
#    'bitrate': 3402083,
#    'encodedType': 'normal',
#    'format': 'mp4',
#    'videoQuality': 'normal',
#    'encodeUserTag': '',
#    'codecType': 'h264',
#    'definition': '720p'},
#   'author': {'id': '6721014986372826118',
#    'uniqueId': 'brianbarczyk',
#    'nickname': 'BrianBarczyk',
#    'avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1640873239646214~c5_100x100.jpeg?x-expires=1644274800&x-signature=B9P9SFZkm5LMdayUHY30NWL0YYc%3D',
#    'avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1640873239646214~c5_720x720.jpeg?x-expires=1644274800&x-signature=t9u80g4nVMxSSTm0ikhzAasolCE%3D',
#    'avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1640873239646214~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=zg5XOSDqMqSSZ8TL6w8k%2FhHLm0Q%3D',
#    'signature': 'Just that animal guy from “The Reptarium” \nin Utica, Michigan🐍🐢🦎🐸',
#    'verified': True,
#    'secUid': 'MS4wLjABAAAArQ-im7e56wITSIolojJ4S0PjoQE4yrb3Y6qI2PJmTZ9cK2q5cJjxia6BzRKFyvAA',
#    'secret': False,
#    'ftc': False,
#    'relation': 0,
#    'openFavorite': False,
#    'commentSetting': 0,
#    'duetSetting': 0,
#    'stitchSetting': 0,
#    'privateAccount': False,
#    'isADVirtual': False},
#   'music': {'id': '6755228142241172230',
#    'title': 'original sound',
#    'playUrl': 'https://sf16-checkout.tiktokcdn.com/obj/musically-maliva-obj/1649321326795798.mp3',
#    'coverThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1640873239646214~c5_100x100.jpeg?x-expires=1644274800&x-signature=B9P9SFZkm5LMdayUHY30NWL0YYc%3D',
#    'coverMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1640873239646214~c5_720x720.jpeg?x-expires=1644274800&x-signature=t9u80g4nVMxSSTm0ikhzAasolCE%3D',
#    'coverLarge': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1640873239646214~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=zg5XOSDqMqSSZ8TL6w8k%2FhHLm0Q%3D',
#    'authorName': 'BrianBarczyk',
#    'original': True,
#    'duration': 31,
#    'album': ''},
#   'challenges': [{'id': '204835',
#     'title': 'reptiles',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '163195',
#     'title': 'python',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '5192',
#     'title': 'animals',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '43268',
#     'title': '4u',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False}],
#   'stats': {'diggCount': 1700000,
#    'shareCount': 21400,
#    'commentCount': 5322,
#    'playCount': 14200000},
#   'duetInfo': {'duetFromId': '0'},
#   'originalItem': False,
#   'officalItem': False,
#   'textExtra': [{'awemeId': '',
#     'start': 37,
#     'end': 46,
#     'hashtagName': 'reptiles',
#     'hashtagId': '204835',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 47,
#     'end': 54,
#     'hashtagName': 'python',
#     'hashtagId': '163195',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 55,
#     'end': 63,
#     'hashtagName': 'animals',
#     'hashtagId': '5192',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 64,
#     'end': 67,
#     'hashtagName': '4u',
#     'hashtagId': '43268',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0}],
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats': {'followingCount': 39,
# ...
#    'shareCover': ['',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/eb1c092cff22449a8223826b4c9fe3b9_1636987104~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=%2BpbXxFoJYPas%2F%2Fw9uhTXqVHvKyY%3D',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/eb1c092cff22449a8223826b4c9fe3b9_1636987104~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=fQHOiSz%2BSDQ95XVyLkE7yFUzn1U%3D'],
#    'reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/e4fd7764e1bcf871f0a41b5a9da16910?x-expires=1644210000&x-signature=7MlvyazOPaQqoIr4L2A6mTvkIdo%3D',
#    'bitrate': 1630585,
#    'encodedType': 'normal',
#    'format': 'mp4',
#    'videoQuality': 'normal',
#    'encodeUserTag': '',
#    'codecType': 'h264',
#    'definition': '720p'},
#   'author': {'id': '6699542567460389894',
#    'uniqueId': 'jayprehistoricpets',
#    'nickname': 'Jay Brewer',
#    'avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_100x100.jpeg?x-expires=1644274800&x-signature=ySoYnE4ZGrNw1UvrWRBvt02%2BkgI%3D',
#    'avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_720x720.jpeg?x-expires=1644274800&x-signature=NmgLKIE46gsC1dtIZwLfG84xu98%3D',
#    'avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=PknVltC49WtWXGM%2FRh%2B3JeI%2BCnI%3D',
#    'signature': 'Sub to my YouTube for even more animal fun see you here on TikTok tomorrow 🤗🙌',
#    'verified': True,
#    'secUid': 'MS4wLjABAAAAKtlitna177EaY3JAgDPnjAfZj8kI-GnaM5hU9HPzaEQzcuj976k3NYbmpX9cyxc2',
#    'secret': False,
#    'ftc': False,
#    'relation': 0,
#    'openFavorite': False,
#    'commentSetting': 0,
#    'duetSetting': 0,
#    'stitchSetting': 0,
#    'privateAccount': False,
#    'isADVirtual': False},
#   'music': {'id': '7030805915611728645',
#    'title': 'original sound',
#    'playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/7030805981353265926.mp3',
#    'coverThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_100x100.jpeg?x-expires=1644274800&x-signature=ySoYnE4ZGrNw1UvrWRBvt02%2BkgI%3D',
#    'coverMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_720x720.jpeg?x-expires=1644274800&x-signature=NmgLKIE46gsC1dtIZwLfG84xu98%3D',
#    'coverLarge': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1635689550192645~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=PknVltC49WtWXGM%2FRh%2B3JeI%2BCnI%3D',
#    'authorName': 'Jay Brewer',
#    'original': True,
#    'duration': 51,
#    'album': ''},
#   'challenges': [{'id': '37769',
#     'title': 'snake',
#     'desc': 'Il trend del momento ♫',
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '27930',
#     'title': 'eggs',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '163195',
#     'title': 'python',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False}],
#   'stats': {'diggCount': 628500,
#    'shareCount': 4669,
#    'commentCount': 3020,
#    'playCount': 8000000},
#   'duetInfo': {'duetFromId': '0'},
#   'originalItem': False,
#   'officalItem': False,
#   'textExtra': [{'awemeId': '',
#     'start': 130,
#     'end': 136,
#     'hashtagName': 'snake',
#     'hashtagId': '37769',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 137,
#     'end': 142,
#     'hashtagName': 'eggs',
#     'hashtagId': '27930',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 143,
#     'end': 150,
#     'hashtagName': 'python',
#     'hashtagId': '163195',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0}],
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats': {'followingCount': 82,
#    'followerCount': 17400000,
#    'heartCount': 232500000,
#    'videoCount': 782,
#    'diggCount': 17200,
#    'heart': 232500000},
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0},
#  {'id': '6920302329358978310',
#   'desc': '🐍🐍 Nasza największa pycia 😈 #molt #gadolandreda #gadoland #reda #noise #snake #omg #foryou #reptile #listen #python',
#   'createTime': 1611258459,
#   'video': {'id': '6920302329358978310',
#    'height': 960,
#    'width': 540,
#    'duration': 12,
#    'ratio': '720p',
#    'cover': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/90d4dda33d64429fb8e09c40e39d8b31_1611258462~tplv-dmt-logom:tos-maliva-p-0000/ada0d60c22184f35b3bb7092441a96fc.image?x-expires=1644210000&x-signature=mm3AC2ltWLdFm2VrO5VocIGN7S4%3D',
#    'originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f47cc650e14144ac86559f5320f5a8cc_1611258461?x-expires=1644210000&x-signature=Hb6QdfLGJu%2FzVkMXLU16srlbls4%3D',
#    'dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/8409cdbf3bfd4042bf566355c3ad9c45_1611258462?x-expires=1644210000&x-signature=F7wLyvxEeJPM3uMNOfUuKS6zH9U%3D',
#    'playAddr': 'https://v16-webapp.tiktok.com/ce1419150257051a1f4a0511d80c272b/6200a87a/video/tos/useast2a/tos-useast2a-pve-0068/99c711d53fa44c619299208ed95636f3/?a=1988&br=4198&bt=2099&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=Mzp4OmR3bzx3MzMzOjczM0ApaTM1NGZnZGQ5N2c4NWRlO2cvMm9zLWhfaDFgLS1iMTZzc14uLTQtMmJjYi0xXmA2NS46Yw%3D%3D&vl=&vr=',
#    'downloadAddr': 'https://v16-webapp.tiktok.com/ce1419150257051a1f4a0511d80c272b/6200a87a/video/tos/useast2a/tos-useast2a-pve-0068/99c711d53fa44c619299208ed95636f3/?a=1988&br=4198&bt=2099&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=3&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=Mzp4OmR3bzx3MzMzOjczM0ApaTM1NGZnZGQ5N2c4NWRlO2cvMm9zLWhfaDFgLS1iMTZzc14uLTQtMmJjYi0xXmA2NS46Yw%3D%3D&vl=&vr=',
#    'shareCover': ['',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/f47cc650e14144ac86559f5320f5a8cc_1611258461~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=G0jff4KmJ8sUfKHjVmUtc9Tw5T0%3D',
#     'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/f47cc650e14144ac86559f5320f5a8cc_1611258461~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=tCkGOoyGLan%2Bc%2FZTFBqUR60DdmA%3D'],
#    'reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/90d4dda33d64429fb8e09c40e39d8b31_1611258462?x-expires=1644210000&x-signature=cOZJwEx%2BimeDfSND9HrqbCQGhng%3D',
#    'bitrate': 2149770,
#    'encodedType': 'normal',
#    'format': 'mp4',
#    'videoQuality': 'normal',
#    'encodeUserTag': '',
#    'codecType': 'h264',
#    'definition': '720p'},
#   'author': {'id': '6824865113461605382',
#    'uniqueId': 'gadoland_reda',
#    'nickname': 'Gadoland Reda 🐍🦎🐊',
#    'avatarThumb': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_100x100.jpeg?x-expires=1644274800&x-signature=FUAqGTAtMaBxOJXicehSut%2F6ugo%3D',
#    'avatarMedium': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_720x720.jpeg?x-expires=1644274800&x-signature=sz8TdaGOcxELgC091pmdeS2KJfA%3D',
#    'avatarLarger': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=yg0wHBNP1XJs5hIeZs3IvjIb7Vk%3D',
#    'signature': 'Life with exotic animals\nKarnawał 5-6 lutego 2022 ! \n📩Gadoland@aquaparkreda.pl',
#    'verified': True,
#    'secUid': 'MS4wLjABAAAAklrDQLWlZI8RIBXXV5UNmo6FGH-amE-eLlwb3mTdBRcKtdObWUkgsjGyc1VM8vQd',
#    'secret': False,
#    'ftc': False,
#    'relation': 0,
#    'openFavorite': False,
#    'commentSetting': 0,
#    'duetSetting': 0,
#    'stitchSetting': 0,
#    'privateAccount': False,
#    'isADVirtual': False},
#   'music': {'id': '6920302341254056709',
#    'title': 'dźwięk oryginalny',
#    'playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6920302317438864134.mp3',
#    'coverThumb': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_100x100.jpeg?x-expires=1644274800&x-signature=FUAqGTAtMaBxOJXicehSut%2F6ugo%3D',
#    'coverMedium': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_720x720.jpeg?x-expires=1644274800&x-signature=sz8TdaGOcxELgC091pmdeS2KJfA%3D',
#    'coverLarge': 'https://p77-sign-va.tiktokcdn.com/musically-maliva-obj/1666228176530437~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=yg0wHBNP1XJs5hIeZs3IvjIb7Vk%3D',
#    'authorName': 'Gadoland Reda 🐍🦎🐊',
#    'original': True,
#    'duration': 11,
#    'album': ''},
#   'challenges': [{'id': '83063156',
#     'title': 'molt',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '1666242978742278',
#     'title': 'gadolandreda',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '1637491150826502',
#     'title': 'gadoland',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '136000',
#     'title': 'reda',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '88607',
#     'title': 'noise',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '37769',
#     'title': 'snake',
#     'desc': 'Il trend del momento ♫',
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/f2f93fdb3bad0411bfc578969384a50a',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '1603',
#     'title': 'omg',
#     'desc': 'Share with us a situation that had you saying: omg!',
#     'profileThumb': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/3d1e6d3d3d2164f415e615e5a4a19430',
#     'profileMedium': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/3d1e6d3d3d2164f415e615e5a4a19430',
#     'profileLarger': 'https://p16-amd-va.tiktokcdn.com/obj/musically-maliva-obj/3d1e6d3d3d2164f415e615e5a4a19430',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '42164',
#     'title': 'foryou',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '132399',
#     'title': 'reptile',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '7889',
#     'title': 'listen',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False},
#    {'id': '163195',
#     'title': 'python',
#     'desc': '',
#     'profileThumb': '',
#     'profileMedium': '',
#     'profileLarger': '',
#     'coverThumb': '',
#     'coverMedium': '',
#     'coverLarger': '',
#     'isCommerce': False}],
#   'stats': {'diggCount': 617300,
#    'shareCount': 12300,
#    'commentCount': 10600,
#    'playCount': 12300000},
#   'duetInfo': {'duetFromId': '0'},
#   'originalItem': False,
#   'officalItem': False,
#   'textExtra': [{'awemeId': '',
#     'start': 31,
#     'end': 36,
#     'hashtagName': 'molt',
#     'hashtagId': '83063156',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 37,
#     'end': 50,
#     'hashtagName': 'gadolandreda',
#     'hashtagId': '1666242978742278',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 51,
#     'end': 60,
#     'hashtagName': 'gadoland',
#     'hashtagId': '1637491150826502',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 61,
#     'end': 66,
#     'hashtagName': 'reda',
#     'hashtagId': '136000',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 67,
#     'end': 73,
#     'hashtagName': 'noise',
#     'hashtagId': '88607',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 74,
#     'end': 80,
#     'hashtagName': 'snake',
#     'hashtagId': '37769',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 81,
#     'end': 85,
#     'hashtagName': 'omg',
#     'hashtagId': '1603',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 86,
#     'end': 93,
#     'hashtagName': 'foryou',
#     'hashtagId': '42164',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 94,
#     'end': 102,
#     'hashtagName': 'reptile',
#     'hashtagId': '132399',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 103,
#     'end': 110,
#     'hashtagName': 'listen',
#     'hashtagId': '7889',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0},
#    {'awemeId': '',
#     'start': 111,
#     'end': 118,
#     'hashtagName': 'python',
#     'hashtagId': '163195',
#     'type': 1,
#     'userId': '',
#     'isCommerce': False,
#     'userUniqueId': '',
#     'secUid': '',
#     'subType': 0}],
#   'secret': False,
#   'forFriend': False,
#   'digged': False,
#   'itemCommentStatus': 0,
#   'showNotPass': False,
#   'vl1': False,
#   'itemMute': False,
#   'authorStats': {'followingCount': 0,
#    'followerCount': 318800,
#    'heartCount': 4700000,
#    'videoCount': 229,
#    'diggCount': 852,
#    'heart': 4700000},
#   'privateItem': False,
#   'duetEnabled': False,
#   'stitchEnabled': False,
#   'shareEnabled': True,
#   'stickersOnItem': [{'stickerType': 4,
#     'stickerText': ['Podoba Ci się ten dźwięk ?😬']},
#    {'stickerType': 9, 'stickerText': ['Musisz posłuchać ❗️']}],
#   'isAd': False,
#   'duetDisplay': 0,
#   'stitchDisplay': 0}]

# %%
nested_values = ["video", "author", "music", "stats", "authorStats", 
                "challenges", "duetInfo", "textExtra", "stickersOnItem"]
skip_values = ["challenges", "duetInfo", "textExtra", "stickersOnItem"]

# %%
# Store data which is already flattened
flattened_data = {}

# Iterate through all to get nested into more flattened
for idx, value in enumerate(data):
    
    # Intialized dictionary for each ID (numbered json item)
    flattened_data[idx] = {}
    
    for prop_idx, prop_value  in value.items():
        
        # If in nested value, we need to expand
        if prop_idx in nested_values:
            
            # Check if we need to skip it
            if prop_idx in skip_values:
                pass
            else:
                # Loop to each nested propeerty in value
                for nested_idx, nested_value in prop_value.items():
                    flattened_data[idx][prop_idx +"_"+nested_idx] = nested_value
        
        # It not nested value, simply add to already flattened data
        else:
            flattened_data[idx][prop_idx] = prop_value

# %%
flattened_data[0]
# Out:
# {'id': '6914157190987271430',
#  'desc': 'Oh Julius 😅 "Julius the Python" on YouTube #juliusthesnake #python #snakes #petsnakes #reptiles #bigsnakes #exoticpet #burmesepython #funnyanimals',
#  'createTime': 1609827712,
#  'video_id': '6914157190987271430',
#  'video_height': 480,
#  'video_width': 640,
#  'video_duration': 9,
#  'video_ratio': '480p',
#  'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8b44ab15bd64f4ba820bc477f485a10_1609827713?x-expires=1644210000&x-signature=SUInSDyvUToj5%2BZdjd4lCFUU%2FBM%3D',
#  'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713?x-expires=1644210000&x-signature=pyNPKSMpCoBdZ62Go0XQC21GyYQ%3D',
#  'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/ec2039a008c24b859c00aa3aa3971c9c_1609827714?x-expires=1644210000&x-signature=QkkKGhPa%2BZLhYKi5k%2F%2FrpoNgwPQ%3D',
#  'video_playAddr': 'https://v16-webapp.tiktok.com/e56e0960f2331c5eb92a95687c6424e9/6200a878/video/tos/useast2a/tos-useast2a-ve-0068c001/027aa7b9454044f98520401bbb5eaf44/?a=1988&br=816&bt=408&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=2&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajV1eXNtNXkzeTMzNTczM0ApNDo8OmY0Mzs3N2lkOzhnZGduNHM2NDAwXm5fLS1fMTZzczIzYy9iYDAyMTJgNjYwYWM6Yw%3D%3D&vl=&vr=',
#  'video_downloadAddr': 'https://v16-webapp.tiktok.com/e56e0960f2331c5eb92a95687c6424e9/6200a878/video/tos/useast2a/tos-useast2a-ve-0068c001/027aa7b9454044f98520401bbb5eaf44/?a=1988&br=816&bt=408&cd=0%7C0%7C1%7C0&ch=0&cr=0&cs=0&cv=1&dr=0&ds=2&er=&ft=XOQ9-3E7nz7ThLkwoDXq&l=202202062304470102510582230BF58E52&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&qs=0&rc=ajV1eXNtNXkzeTMzNTczM0ApNDo8OmY0Mzs3N2lkOzhnZGduNHM2NDAwXm5fLS1fMTZzczIzYy9iYDAyMTJgNjYwYWM6Yw%3D%3D&vl=&vr=',
#  'video_shareCover': ['',
#   'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713~tplv-tiktok-play.jpeg?x-expires=1644793200&x-signature=shoOWtTHh27WBO1ZfJBNY%2FUyE2M%3D',
#   'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713~tplv-tiktokx-share-play.jpeg?x-expires=1644793200&x-signature=WoHTEYASSjN3wuS3READto9f84w%3D'],
#  'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8b44ab15bd64f4ba820bc477f485a10_1609827713?x-expires=1644210000&x-signature=SUInSDyvUToj5%2BZdjd4lCFUU%2FBM%3D',
#  'video_bitrate': 418808,
#  'video_encodedType': 'normal',
#  'video_format': 'mp4',
#  'video_videoQuality': 'normal',
#  'video_encodeUserTag': '',
#  'video_codecType': 'h264',
#  'video_definition': '480p',
#  'author_id': '6815401436291580934',
#  'author_uniqueId': '666zomey',
#  'author_nickname': 'Zomey',
#  'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_100x100.jpeg?x-expires=1644274800&x-signature=s6cfURS%2BvYpA3UZRITQMdJ%2BOn%2FA%3D',
#  'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_720x720.jpeg?x-expires=1644274800&x-signature=HxG4uLswBqFSVnxh%2BGftMdKAIQM%3D',
#  'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=%2B6JIHFjIYl4SzGFAN%2FR%2BHx56HZ8%3D',
#  'author_signature': "~ PDX. 🏳️\u200d🌈. Wine. Animals. Humor ~\nInsta '666zomey'\n$zomey666",
#  'author_verified': False,
#  'author_secUid': 'MS4wLjABAAAAmKLjce6rFzxV0HuEfYOm5dh-tCsyPyhTdnqj-ebq1Hozp7r91zmbf3-6UirgSZhm',
#  'author_secret': False,
#  'author_ftc': False,
#  'author_relation': 0,
#  'author_openFavorite': False,
#  'author_commentSetting': 0,
#  'author_duetSetting': 0,
#  'author_stitchSetting': 0,
#  'author_privateAccount': False,
#  'author_isADVirtual': False,
#  'music_id': '6914157155620801286',
#  'music_title': 'original sound',
#  'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6914157149086108421.mp3',
#  'music_coverThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_100x100.jpeg?x-expires=1644274800&x-signature=s6cfURS%2BvYpA3UZRITQMdJ%2BOn%2FA%3D',
#  'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_720x720.jpeg?x-expires=1644274800&x-signature=HxG4uLswBqFSVnxh%2BGftMdKAIQM%3D',
#  'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_1080x1080.jpeg?x-expires=1644274800&x-signature=%2B6JIHFjIYl4SzGFAN%2FR%2BHx56HZ8%3D',
#  'music_authorName': 'Zomey',
#  'music_original': True,
#  'music_duration': 8,
#  'music_album': '',
#  'challenges': [{'id': '1688028247347206',
#    'title': 'juliusthesnake',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False},
#   {'id': '163195',
#    'title': 'python',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False},
#   {'id': '55989',
#    'title': 'snakes',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False},
#   {'id': '12175144',
#    'title': 'petsnakes',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False},
#   {'id': '204835',
#    'title': 'reptiles',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False},
#   {'id': '14708816',
#    'title': 'bigsnakes',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False},
#   {'id': '12390175',
#    'title': 'exoticpet',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False},
#   {'id': '17154764',
#    'title': 'burmesepython',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False},
#   {'id': '487800',
#    'title': 'funnyanimals',
#    'desc': '',
#    'profileThumb': '',
#    'profileMedium': '',
#    'profileLarger': '',
#    'coverThumb': '',
#    'coverMedium': '',
#    'coverLarger': '',
#    'isCommerce': False}],
#  'stats_diggCount': 3500000,
#  'stats_shareCount': 271800,
#  'stats_commentCount': 72900,
#  'stats_playCount': 26600000,
#  'duetInfo': {'duetFromId': '0'},
#  'originalItem': False,
#  'officalItem': False,
#  'textExtra': [{'awemeId': '',
#    'start': 44,
#    'end': 59,
#    'hashtagName': 'juliusthesnake',
#    'hashtagId': '1688028247347206',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 60,
#    'end': 67,
#    'hashtagName': 'python',
#    'hashtagId': '163195',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 68,
#    'end': 75,
#    'hashtagName': 'snakes',
#    'hashtagId': '55989',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 76,
#    'end': 86,
#    'hashtagName': 'petsnakes',
#    'hashtagId': '12175144',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 87,
#    'end': 96,
#    'hashtagName': 'reptiles',
#    'hashtagId': '204835',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 97,
#    'end': 107,
#    'hashtagName': 'bigsnakes',
#    'hashtagId': '14708816',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 108,
#    'end': 118,
#    'hashtagName': 'exoticpet',
#    'hashtagId': '12390175',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 119,
#    'end': 133,
#    'hashtagName': 'burmesepython',
#    'hashtagId': '17154764',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 134,
#    'end': 147,
#    'hashtagName': 'funnyanimals',
#    'hashtagId': '487800',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0}],
#  'secret': False,
#  'forFriend': False,
#  'digged': False,
#  'itemCommentStatus': 0,
#  'showNotPass': False,
#  'vl1': False,
#  'itemMute': False,
#  'authorStats_followingCount': 737,
#  'authorStats_followerCount': 105100,
#  'authorStats_heartCount': 4700000,
#  'authorStats_videoCount': 192,
#  'authorStats_diggCount': 3583,
#  'authorStats_heart': 4700000,
#  'privateItem': False,
#  'duetEnabled': True,
#  'stitchEnabled': True,
#  'shareEnabled': True,
#  'stickersOnItem': [{'stickerType': 4,
#    'stickerText': ['That time my girlfriends python, Julius... ',
#     'Learned how to open doors 😅']}],
#  'isAd': False,
#  'duetDisplay': 0,
#  'stitchDisplay': 0}

# %%
pd.DataFrame.from_dict(flattened_data, orient="index")
# Out:
#                      id                                               desc  \
# 0   6914157190987271430  Oh Julius 😅 "Julius the Python" on YouTube #ju...
# 1   6909838234151423234  stain.. Petit python banana..😍#fyp  #ballpytho...
# 2   6958430060340694278  Happy birthday little buddy 🐍 #snake #python #...
# 3   6980527845726604549  lil too busy worried about snacks.. #Python #d...
# 4   6840796191161175302  Check out this baby python! Did you kno their ...
# 5   6755879345597828357  Helping my 20 foot pet snake shed... #reptiles...
# 6   6998487128254483718  computer automatically alt-tabs when door is o...
# 7   7015946767283850502  You never know what’ll be in the egg 😯 #snake ...
# 8   6933762096479866118  THEY SCARED😂@jmontt @zwifty2k #viral #foryoupa...
# 9   7019396141955517701  She a lil… dramatic #snakes #snake #ballpython...
# 10  6905682583682551042  #snake#satisfying#satisfyingvideo#snakesheddin...
# 11  7029626294124039426  Reply to @cookies_critters  this  female albin...
# 12  6995583470185483525  NO SNEKS WERE HARMED, it’s just a joke ❤️🐍🔥 #b...
# 13  6871013592720788742  DREAMS CAME TRUE LAST NIGHT!!!!! 8+ foot Burme...
# 14  7035635040679759110                          #программирование #python
# 15  6840818955209182470  Meet Grillled Cheese, our albino dwarf Burmese...
# 16  6867909441103088902  This 16 foot wild Burmese python escaped into ...
# 17  7010993830774295810  Playing guitar for this wild danger noodle 🐍  ...
# 18  6890221660805287173  THROWBACK TO MY FAVORITE CATCH OF THE YEAR!!! ...
# 19  7028950491283361029  This Burmese python is HUGE 😱 it’s trying to s...
# 20  6954131473645440262  i had someone babysit juno and she gave her aw...
# 21  7033674978511899905  Loops are for the weak 😤  #fypシ #compsci #tech...
# 22  6812265312122146054  Snuggles  the Snake. #snugglesthesnake #snake ...
# 23  6993395942699355397  Cleaning the BIG SNAKES! 🐍 #TeamofTomorrow #bu...
# 24  7019633115710655746  RED TEAM LETS WIN THIS!!!! 😤 #fypシ #mcyt #stre...
# 25  6994298773451197701                    #minecraft #python #programming
# 26  7025925379982413062  Cómo cagarla con orgullo siendo programador #t...
# 27  6985505326913031429  💪🏽 #coding #gaming #flappybird #ursinaengine #...
# 28  7030806068859112709  Mama python wasn’t happy 😬 she has no idea we ...
# 29  6920302329358978310  🐍🐍 Nasza największa pycia 😈 #molt #gadolandred...
#
#     createTime             video_id  video_height  video_width  \
# 0   1609827712  6914157190987271430           480          640
# 1   1608822085  6909838234151423234           960          540
# 2   1620135755  6958430060340694278          1024          576
# 3   1625280797  6980527845726604549          1024          576
# 4   1592746983  6840796191161175302          1024          576
# 5   1572975739  6755879345597828357          1280          720
# 6   1629462265  6998487128254483718           576          576
# 7   1633527403  7015946767283850502          1024          576
# 8   1614392308  6933762096479866118          1024          576
# 9   1634330523  7019396141955517701          1016          540
# 10  1607854522  6905682583682551042           960          540
# 11  1636712416  7029626294124039426          1024          576
# 12  1628786203  6995583470185483525          1024          576
# 13  1599782529  6871013592720788742          1024          576
# 14  1638111436  7035635040679759110          1024          576
# 15  1592752283  6840818955209182470          1024          576
# 16  1599059793  6867909441103088902          1082          576
# 17  1632374208  7010993830774295810          1012          576
# 18  1604254781  6890221660805287173          1024          576
# 19  1636555068  7028950491283361029          1024          576
# 20  1619134911  6954131473645440262          1024          576
# 21  1637655074  7033674978511899905           960          540
# 22  1586104120  6812265312122146054          1024          576
# 23  1628276879  6993395942699355397          1024          576
# 24  1634385697  7019633115710655746           960          540
# 25  1628487089  6994298773451197701          1024          576
# 26  1635850730  7025925379982413062          1024          576
# 27  1626439706  6985505326913031429          1024          576
# 28  1636987104  7030806068859112709          1024          576
# 29  1611258459  6920302329358978310           960          540
#
#     video_duration video_ratio  \
# 0                9        480p
# 1               15        720p
# 2               20        720p
# 3                7        720p
# 4               18        720p
# 5               31        720p
# 6               11        720p
# 7               45        720p
# 8               56        720p
# 9                7        720p
# 10              13        720p
# 11              78        720p
# 12               6        720p
# 13              20        720p
# 14              39        720p
# 15              14        720p
# 16              22        720p
# 17              14        720p
# 18              15        720p
# 19              13        720p
# 20              15        720p
# 21              11        720p
# 22              15        720p
# 23              61        720p
# 24              26        720p
# 25              45        720p
# 26              59        720p
# 27              36        720p
# 28              51        720p
# 29              12        720p
#
#                                           video_cover  \
# 0   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1   https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 2   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 3   https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 4   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 5   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 6   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 7   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 8   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 9   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 10  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 11  https://p16-sign-sg.tiktokcdn.com/tos-alisg-p-...
# 12  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 13  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 14  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 15  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 16  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 17  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 18  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 19  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 20  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 21  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 22  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 23  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 24  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 25  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 26  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 27  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 28  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 29  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
#
#                                     video_originCover  ... privateItem  \
# 0   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 1   https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...       False
# 2   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 3   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 4   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 5   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 6   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 7   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 8   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 9   https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 10  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...       False
# 11  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...       False
# 12  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 13  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 14  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 15  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 16  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 17  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...       False
# 18  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 19  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 20  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 21  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...       False
# 22  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 23  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 24  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...       False
# 25  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 26  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 27  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 28  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
# 29  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...       False
#
#    duetEnabled stitchEnabled shareEnabled  \
# 0         True          True         True
# 1        False         False         True
# 2        False         False         True
# 3         True          True         True
# 4         True          True         True
# 5        False          True         True
# 6         True          True         True
# 7        False         False         True
# 8         True          True         True
# 9         True          True         True
# 10        True          True         True
# 11       False         False         True
# 12        True          True         True
# 13        True          True         True
# 14        True          True         True
# 15        True          True         True
# 16        True          True         True
# 17        True          True         True
# 18        True          True         True
# 19        True          True         True
# 20        True          True         True
# 21        True          True         True
# 22       False          True         True
# 23        True          True         True
# 24        True          True         True
# 25        True          True         True
# 26        True          True         True
# 27        True          True         True
# 28       False         False         True
# 29       False         False         True
#
#                                        stickersOnItem   isAd duetDisplay  \
# 0   [{'stickerType': 4, 'stickerText': ['That time...  False           0
# 1                                                 NaN  False           0
# 2                                                 NaN  False           0
# 3   [{'stickerType': 9, 'stickerText': ['Dog steps...  False           0
# 4                                                 NaN  False           0
# 5                                                 NaN  False           0
# 6                                                 NaN  False           0
# 7   [{'stickerType': 4, 'stickerText': ['What’s in...  False           0
# 8   [{'stickerType': 4, 'stickerText': ['I TOLD MY...  False           0
# 9                                                 NaN  False           0
# 10                                                NaN  False           0
# 11  [{'stickerType': 4, 'stickerText': ['This fema...  False           0
# 12  [{'stickerType': 9, 'stickerText': ['🔥 B U R N...  False           0
# 13                                                NaN  False           0
# 14  [{'stickerType': 4, 'stickerText': ['Младший б...  False           0
# 15                                                NaN  False           0
# 16                                                NaN  False           0
# 17                                                NaN  False           0
# 18                                                NaN  False           0
# 19                                                NaN  False           0
# 20  [{'stickerType': 4, 'stickerText': ['so this i...  False           0
# 21  [{'stickerType': 4, 'stickerText': ['I just wr...  False           0
# 22  [{'stickerType': 4, 'stickerText': ['Eye
# of t...  False           0
# 23                                                NaN  False           0
# 24                                                NaN  False           0
# 25  [{'stickerType': 9, 'stickerText': ['Minecraft...  False           0
# 26  [{'stickerType': 4, 'stickerText': ['Cómo caga...  False           0
# 27  [{'stickerType': 4, 'stickerText': ['“You can’...  False           0
# 28                                                NaN  False           0
# 29  [{'stickerType': 4, 'stickerText': ['Podoba Ci...  False           0
#
#    stitchDisplay                                           warnInfo  \
# 0              0                                                NaN
# 1              0                                                NaN
# 2              0                                                NaN
# 3              0                                                NaN
# 4              0                                                NaN
# 5              0                                                NaN
# 6              0                                                NaN
# 7              0                                                NaN
# 8              0                                                NaN
# 9              0                                                NaN
# 10             0                                                NaN
# 11             0                                                NaN
# 12             0                                                NaN
# 13             0                                                NaN
# 14             0                                                NaN
# 15             0  [{'text': 'Participating in this activity coul...
# 16             0  [{'text': 'Participating in this activity coul...
# 17             0                                                NaN
# 18             0                                                NaN
# 19             0                                                NaN
# 20             0                                                NaN
# 21             0                                                NaN
# 22             0                                                NaN
# 23             0                                                NaN
# 24             0                                                NaN
# 25             0                                                NaN
# 26             0                                                NaN
# 27             0                                                NaN
# 28             0                                                NaN
# 29             0                                                NaN
#
#                                        effectStickers
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  [{'name': 'Green Screen Video', 'ID': '454747'...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 82 columns]
